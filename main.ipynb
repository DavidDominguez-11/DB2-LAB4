# %%
from pymongo import MongoClient
def get_database():
 
   # Provide the mongodb atlas url to connect python to mongodb using pymongo
   CONNECTION_STRING = "mongodb+srv://dom_db_user:admin@cluster0.0iqynvo.mongodb.net/?appName=Cluster0"
 
   # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
   client = MongoClient(CONNECTION_STRING)
 
   # Create the database for our example (we will use the same database throughout the tutorial
   return client['lab04']

# %%
dbname = get_database()
print(dbname)
# Out:
# Database(MongoClient(host=['ac-cm3bhfl-shard-00-02.0iqynvo.mongodb.net:27017', 'ac-cm3bhfl-shard-00-01.0iqynvo.mongodb.net:27017', 'ac-cm3bhfl-shard-00-00.0iqynvo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-ld3n58-shard-0', tls=True), 'lab04')

# %%
dbname = get_database()
collection_name = dbname["user_1_items"]

item_1 = {
  "_id" : "U1IT00001",
  "item_name" : "Blender",
  "max_discount" : "10%",
  "batch_number" : "RR450020FRG",
  "price" : 340,
  "category" : "kitchen appliance"
}

item_2 = {
  "_id" : "U1IT00002",
  "item_name" : "Egg",
  "category" : "food",
  "quantity" : 12,
  "price" : 36,
  "item_description" : "brown country eggs"
}
collection_name.insert_many([item_1,item_2])
# Out:
# InsertManyResult(['U1IT00001', 'U1IT00002'], acknowledged=True)
